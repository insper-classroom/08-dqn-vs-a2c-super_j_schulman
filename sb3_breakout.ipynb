# %%
from stable_baselines3 import PPO, DQN, A2C
import gymnasium as gym
import ale_py

gym.register_envs(ale_py)  # unnecessary but helpful for IDEs

from stable_baselines3.common.logger import configure
from stable_baselines3.common.evaluation import evaluate_policy

tmp_path = "./results/a2c-breakout"
new_logger = configure(tmp_path, ["stdout", "csv", "tensorboard"])

env = gym.make("ALE/Breakout-v5")
model = A2C(policy = "MlpPolicy", env = env)

model.set_logger(new_logger)
model.learn(total_timesteps=100_000)

mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)
print(f'Mean reward: {mean_reward} +/- {std_reward:.2f}')
# Out:
# Logging to ./results/a2c-breakout
# c:\Users\gabri\anaconda3\envs\rl\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run A2C on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 164       |
# |    ep_rew_mean        | 0.667     |
# | time/                 |           |
# |    fps                | 129       |
# |    iterations         | 100       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -1.37     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -5.08e-07 |
# |    value_loss         | 2.95e-13  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 194      |
# |    ep_rew_mean        | 1.4      |
# | time/                 |          |
# |    fps                | 138      |
# |    iterations         | 200      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.03    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.00313  |
# |    value_loss         | 8.58e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 190      |
# |    ep_rew_mean        | 1.57     |
# | time/                 |          |
# |    fps                | 139      |
# |    iterations         | 300      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.983   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.00502 |
# |    value_loss         | 4.85e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 186      |
# |    ep_rew_mean        | 1.6      |
# | time/                 |          |
# |    fps                | 139      |
# |    iterations         | 400      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.936   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.00256 |
# |    value_loss         | 1.09e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 191       |
# |    ep_rew_mean        | 1.85      |
# | time/                 |           |
# |    fps                | 138       |
# |    iterations         | 500       |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -0.47     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 0.000477  |
# |    value_loss         | 1.53e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 2.2      |
# | time/                 |          |
# |    fps                | 139      |
# |    iterations         | 600      |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.326   |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.00563 |
# |    value_loss         | 5.78e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 208       |
# |    ep_rew_mean        | 2.25      |
# | time/                 |           |
# |    fps                | 140       |
# |    iterations         | 700       |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -0.198    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -0.000125 |
# |    value_loss         | 1.12e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 229       |
# |    ep_rew_mean        | 2.53      |
# | time/                 |           |
# |    fps                | 145       |
# |    iterations         | 800       |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -0.154    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -5.74e-05 |
# |    value_loss         | 4.5e-06   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 244      |
# |    ep_rew_mean        | 2.78     |
# | time/                 |          |
# |    fps                | 148      |
# |    iterations         | 900      |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.128   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.00166 |
# |    value_loss         | 1.07e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 244       |
# |    ep_rew_mean        | 2.78      |
# | time/                 |           |
# |    fps                | 149       |
# |    iterations         | 1000      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -0.0964   |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -3.15e-08 |
# |    value_loss         | 4.64e-12  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 265       |
# |    ep_rew_mean        | 3.21      |
# | time/                 |           |
# |    fps                | 152       |
# |    iterations         | 1100      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -0.0728   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -7.01e-05 |
# |    value_loss         | 4.3e-05   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 284       |
# |    ep_rew_mean        | 3.2       |
# | time/                 |           |
# |    fps                | 153       |
# |    iterations         | 1200      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -0.0714   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -2.48e-08 |
# |    value_loss         | 5.53e-12  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 308       |
# |    ep_rew_mean        | 3.19      |
# | time/                 |           |
# |    fps                | 154       |
# |    iterations         | 1300      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -0.0598   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | -1.95e-06 |
# |    value_loss         | 5.39e-08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 308       |
# |    ep_rew_mean        | 3.19      |
# | time/                 |           |
# |    fps                | 156       |
# |    iterations         | 1400      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -0.0538   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -2.12e-05 |
# |    value_loss         | 8.22e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 308       |
# |    ep_rew_mean        | 3.19      |
# | time/                 |           |
# |    fps                | 156       |
# |    iterations         | 1500      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -0.0533   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -1.68e-06 |
# |    value_loss         | 5.28e-08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 346       |
# |    ep_rew_mean        | 3.18      |
# | time/                 |           |
# |    fps                | 157       |
# |    iterations         | 1600      |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -0.0251   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -1.17e-05 |
# |    value_loss         | 1.51e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 346       |
# |    ep_rew_mean        | 3.18      |
# | time/                 |           |
# |    fps                | 158       |
# |    iterations         | 1700      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -0.0253   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -5.22e-06 |
# |    value_loss         | 2.96e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 390       |
# |    ep_rew_mean        | 3.52      |
# | time/                 |           |
# |    fps                | 159       |
# |    iterations         | 1800      |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -0.0233   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -1.3e-06  |
# |    value_loss         | 2.24e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 390       |
# |    ep_rew_mean        | 3.52      |
# | time/                 |           |
# |    fps                | 160       |
# |    iterations         | 1900      |
# |    time_elapsed       | 59        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -0.0215   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | -5.35e-06 |
# |    value_loss         | 4.57e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 390       |
# |    ep_rew_mean        | 3.52      |
# | time/                 |           |
# |    fps                | 161       |
# |    iterations         | 2000      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.0224   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | -2.63e-11 |
# |    value_loss         | 4.73e-15  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 390       |
# |    ep_rew_mean        | 3.52      |
# | time/                 |           |
# |    fps                | 161       |
# |    iterations         | 2100      |
# |    time_elapsed       | 64        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -0.0188   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | -3.45e-06 |
# |    value_loss         | 2.59e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 454      |
# |    ep_rew_mean        | 3.67     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 2200     |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.0163  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 2e-08    |
# |    value_loss         | 1.23e-10 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 454      |
# |    ep_rew_mean        | 3.67     |
# | time/                 |          |
# |    fps                | 162      |
# |    iterations         | 2300     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.0163  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 5.9e-11  |
# |    value_loss         | 1.9e-16  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 454       |
# |    ep_rew_mean        | 3.67      |
# | time/                 |           |
# |    fps                | 162       |
# |    iterations         | 2400      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -0.015    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | -1.15e-12 |
# |    value_loss         | 4.89e-19  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 454       |
# |    ep_rew_mean        | 3.67      |
# | time/                 |           |
# |    fps                | 161       |
# |    iterations         | 2500      |
# |    time_elapsed       | 77        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -0.015    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | -8.84e-11 |
# |    value_loss         | 5.46e-15  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 454       |
# |    ep_rew_mean        | 3.67      |
# | time/                 |           |
# |    fps                | 162       |
# |    iterations         | 2600      |
# |    time_elapsed       | 80        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -0.0137   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | -1.89e-07 |
# |    value_loss         | 1.62e-08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 454       |
# |    ep_rew_mean        | 3.67      |
# | time/                 |           |
# |    fps                | 159       |
# |    iterations         | 2700      |
# |    time_elapsed       | 84        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -0.0137   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | -4.52e-13 |
# |    value_loss         | 3.59e-15  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 454       |
# |    ep_rew_mean        | 3.67      |
# | time/                 |           |
# |    fps                | 157       |
# |    iterations         | 2800      |
# |    time_elapsed       | 89        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -0.0137   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | -4.75e-11 |
# |    value_loss         | 1.83e-16  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 454      |
# |    ep_rew_mean        | 3.67     |
# | time/                 |          |
# |    fps                | 155      |
# |    iterations         | 2900     |
# |    time_elapsed       | 93       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.0137  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 5.49e-11 |
# |    value_loss         | 1.37e-15 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 454      |
# |    ep_rew_mean        | 3.67     |
# | time/                 |          |
# |    fps                | 155      |
# |    iterations         | 3000     |
# |    time_elapsed       | 96       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.0137  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 1.99e-10 |
# |    value_loss         | 3.6e-14  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 454      |
# |    ep_rew_mean        | 3.67     |
# | time/                 |          |
# |    fps                | 155      |
# |    iterations         | 3100     |
# |    time_elapsed       | 99       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.0138  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 6.82e-07 |
# |    value_loss         | 2.1e-07  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 454      |
# |    ep_rew_mean        | 3.67     |
# | time/                 |          |
# |    fps                | 155      |
# |    iterations         | 3200     |
# |    time_elapsed       | 102      |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.0128  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 1.51e-07 |
# |    value_loss         | 1.21e-08 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 641       |
# |    ep_rew_mean        | 3.6       |
# | time/                 |           |
# |    fps                | 154       |
# |    iterations         | 3300      |
# |    time_elapsed       | 106       |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -0.00998  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | -8.96e-08 |
# |    value_loss         | 7.61e-09  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 641      |
# |    ep_rew_mean        | 3.6      |
# | time/                 |          |
# |    fps                | 155      |
# |    iterations         | 3400     |
# |    time_elapsed       | 109      |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.00999 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 3.84e-11 |
# |    value_loss         | 8.98e-15 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 641      |
# |    ep_rew_mean        | 3.6      |
# | time/                 |          |
# |    fps                | 155      |
# |    iterations         | 3500     |
# |    time_elapsed       | 112      |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.00852 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | -6.6e-06 |
# |    value_loss         | 5.89e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 641      |
# |    ep_rew_mean        | 3.6      |
# | time/                 |          |
# |    fps                | 156      |
# |    iterations         | 3600     |
# |    time_elapsed       | 115      |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.00957 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 1.66e-11 |
# |    value_loss         | 2.85e-16 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 641       |
# |    ep_rew_mean        | 3.6       |
# | time/                 |           |
# |    fps                | 157       |
# |    iterations         | 3700      |
# |    time_elapsed       | 117       |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -0.00957  |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | -6.86e-12 |
# |    value_loss         | 4.89e-17  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 641       |
# |    ep_rew_mean        | 3.6       |
# | time/                 |           |
# |    fps                | 157       |
# |    iterations         | 3800      |
# |    time_elapsed       | 120       |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -0.00957  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | 1.19e-10  |
# |    value_loss         | 1.48e-14  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 641       |
# |    ep_rew_mean        | 3.6       |
# | time/                 |           |
# |    fps                | 158       |
# |    iterations         | 3900      |
# |    time_elapsed       | 123       |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -0.00957  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -6.43e-11 |
# |    value_loss         | 7.68e-16  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 641       |
# |    ep_rew_mean        | 3.6       |
# | time/                 |           |
# |    fps                | 159       |
# |    iterations         | 4000      |
# |    time_elapsed       | 125       |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.00878  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | -2.91e-06 |
# |    value_loss         | 1.07e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 641      |
# |    ep_rew_mean        | 3.6      |
# | time/                 |          |
# |    fps                | 159      |
# |    iterations         | 4100     |
# |    time_elapsed       | 128      |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -0.00682 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 2.66e-11 |
# |    value_loss         | 9.39e-15 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 641       |
# |    ep_rew_mean        | 3.6       |
# | time/                 |           |
# |    fps                | 158       |
# |    iterations         | 4200      |
# |    time_elapsed       | 132       |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -0.00682  |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | -7.06e-11 |
# |    value_loss         | 2.59e-14  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 641       |
# |    ep_rew_mean        | 3.6       |
# | time/                 |           |
# |    fps                | 158       |
# |    iterations         | 4300      |
# |    time_elapsed       | 135       |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -0.00682  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | -2.81e-11 |
# |    value_loss         | 1.75e-15  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 641       |
# |    ep_rew_mean        | 3.6       |
# | time/                 |           |
# |    fps                | 157       |
# |    iterations         | 4400      |
# |    time_elapsed       | 139       |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -0.00682  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | -1.43e-13 |
# |    value_loss         | 4.53e-20  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 157      |
# |    iterations         | 4500     |
# |    time_elapsed       | 142      |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -0.00677 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 4.81e-09 |
# |    value_loss         | 5.44e-11 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 858       |
# |    ep_rew_mean        | 3.73      |
# | time/                 |           |
# |    fps                | 157       |
# |    iterations         | 4600      |
# |    time_elapsed       | 146       |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -0.00677  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | -9.2e-12  |
# |    value_loss         | 5.24e-15  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 156      |
# |    iterations         | 4700     |
# |    time_elapsed       | 149      |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -0.00677 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 1.59e-11 |
# |    value_loss         | 5.71e-16 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 156      |
# |    iterations         | 4800     |
# |    time_elapsed       | 153      |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.00676 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 8.33e-11 |
# |    value_loss         | 7.08e-15 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 858       |
# |    ep_rew_mean        | 3.73      |
# | time/                 |           |
# |    fps                | 156       |
# |    iterations         | 4900      |
# |    time_elapsed       | 156       |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -0.00676  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | 1.08e-10  |
# |    value_loss         | 4.76e-14  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 156      |
# |    iterations         | 5000     |
# |    time_elapsed       | 160      |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -0.00676 |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 8.71e-11 |
# |    value_loss         | 6.53e-15 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 858       |
# |    ep_rew_mean        | 3.73      |
# | time/                 |           |
# |    fps                | 155       |
# |    iterations         | 5100      |
# |    time_elapsed       | 163       |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -0.00422  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | -5.16e-13 |
# |    value_loss         | 1.75e-18  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 858       |
# |    ep_rew_mean        | 3.73      |
# | time/                 |           |
# |    fps                | 155       |
# |    iterations         | 5200      |
# |    time_elapsed       | 166       |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -0.00422  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | -5.16e-13 |
# |    value_loss         | 1.75e-18  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 858       |
# |    ep_rew_mean        | 3.73      |
# | time/                 |           |
# |    fps                | 155       |
# |    iterations         | 5300      |
# |    time_elapsed       | 170       |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -0.00422  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | -3.38e-13 |
# |    value_loss         | 7.51e-19  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 858       |
# |    ep_rew_mean        | 3.73      |
# | time/                 |           |
# |    fps                | 155       |
# |    iterations         | 5400      |
# |    time_elapsed       | 173       |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -0.00422  |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | -2.49e-11 |
# |    value_loss         | 7.31e-16  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 155      |
# |    iterations         | 5500     |
# |    time_elapsed       | 176      |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -0.00422 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 2.59e-11 |
# |    value_loss         | 1.52e-14 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 155      |
# |    iterations         | 5600     |
# |    time_elapsed       | 180      |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -0.00422 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 3.48e-08 |
# |    value_loss         | 7.95e-09 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 155      |
# |    iterations         | 5700     |
# |    time_elapsed       | 183      |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -0.00422 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | 4.63e-08 |
# |    value_loss         | 1.41e-08 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 154      |
# |    iterations         | 5800     |
# |    time_elapsed       | 187      |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -0.00422 |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 5.6e-07  |
# |    value_loss         | 2.06e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 154      |
# |    iterations         | 5900     |
# |    time_elapsed       | 190      |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -0.00422 |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | 4.38e-07 |
# |    value_loss         | 1.26e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 154      |
# |    iterations         | 6000     |
# |    time_elapsed       | 193      |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.00422 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 3.38e-07 |
# |    value_loss         | 7.5e-07  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 858       |
# |    ep_rew_mean        | 3.73      |
# | time/                 |           |
# |    fps                | 154       |
# |    iterations         | 6100      |
# |    time_elapsed       | 197       |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -0.0056   |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6099      |
# |    policy_loss        | -3.58e-11 |
# |    value_loss         | 7.9e-16   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 858       |
# |    ep_rew_mean        | 3.73      |
# | time/                 |           |
# |    fps                | 154       |
# |    iterations         | 6200      |
# |    time_elapsed       | 200       |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -0.0056   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | -4.01e-11 |
# |    value_loss         | 1.72e-14  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 154      |
# |    iterations         | 6300     |
# |    time_elapsed       | 204      |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -0.0056  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 1.64e-14 |
# |    value_loss         | 9.25e-22 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 153      |
# |    iterations         | 6400     |
# |    time_elapsed       | 207      |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -0.0056  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | 1.64e-14 |
# |    value_loss         | 9.25e-22 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 153      |
# |    iterations         | 6500     |
# |    time_elapsed       | 211      |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -0.0056  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | 1.64e-14 |
# |    value_loss         | 9.25e-22 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 153      |
# |    iterations         | 6600     |
# |    time_elapsed       | 214      |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -0.0056  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | 1.64e-14 |
# |    value_loss         | 9.25e-22 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 153      |
# |    iterations         | 6700     |
# |    time_elapsed       | 218      |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -0.0056  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 1.64e-14 |
# |    value_loss         | 9.25e-22 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 153      |
# |    iterations         | 6800     |
# |    time_elapsed       | 222      |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.0056  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | 1.64e-14 |
# |    value_loss         | 9.25e-22 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 152      |
# |    iterations         | 6900     |
# |    time_elapsed       | 225      |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -0.0056  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | 1.64e-14 |
# |    value_loss         | 9.25e-22 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 152      |
# |    iterations         | 7000     |
# |    time_elapsed       | 229      |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -0.0056  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | 8.18e-15 |
# |    value_loss         | 2.31e-22 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 152      |
# |    iterations         | 7100     |
# |    time_elapsed       | 232      |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -0.0056  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | 8.18e-15 |
# |    value_loss         | 2.31e-22 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 152      |
# |    iterations         | 7200     |
# |    time_elapsed       | 236      |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -0.0056  |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | -0       |
# |    value_loss         | 0        |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 151      |
# |    iterations         | 7300     |
# |    time_elapsed       | 240      |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -0.0056  |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | -0       |
# |    value_loss         | 0        |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 150      |
# |    iterations         | 7400     |
# |    time_elapsed       | 245      |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -0.0056  |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | -0       |
# |    value_loss         | 0        |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 858      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# ...
# |    ep_rew_mean        | 3.86     |
# | time/                 |          |
# |    fps                | 126      |
# |    iterations         | 17600    |
# |    time_elapsed       | 695      |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -0.0066  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17599    |
# |    policy_loss        | 1.18e-12 |
# |    value_loss         | 3.33e-18 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.95e+03  |
# |    ep_rew_mean        | 3.86      |
# | time/                 |           |
# |    fps                | 126       |
# |    iterations         | 17700     |
# |    time_elapsed       | 701       |
# |    total_timesteps    | 88500     |
# | train/                |           |
# |    entropy_loss       | -0.0066   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17699     |
# |    policy_loss        | -4.23e-11 |
# |    value_loss         | 7.68e-16  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.95e+03  |
# |    ep_rew_mean        | 3.86      |
# | time/                 |           |
# |    fps                | 125       |
# |    iterations         | 17800     |
# |    time_elapsed       | 707       |
# |    total_timesteps    | 89000     |
# | train/                |           |
# |    entropy_loss       | -0.0066   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17799     |
# |    policy_loss        | -4.23e-11 |
# |    value_loss         | 7.68e-16  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.95e+03  |
# |    ep_rew_mean        | 3.86      |
# | time/                 |           |
# |    fps                | 125       |
# |    iterations         | 17900     |
# |    time_elapsed       | 713       |
# |    total_timesteps    | 89500     |
# | train/                |           |
# |    entropy_loss       | -0.0066   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17899     |
# |    policy_loss        | -4.23e-11 |
# |    value_loss         | 7.68e-16  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.95e+03  |
# |    ep_rew_mean        | 3.86      |
# | time/                 |           |
# |    fps                | 125       |
# |    iterations         | 18000     |
# |    time_elapsed       | 719       |
# |    total_timesteps    | 90000     |
# | train/                |           |
# |    entropy_loss       | -0.00662  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17999     |
# |    policy_loss        | -3.45e-11 |
# |    value_loss         | 1.22e-14  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.95e+03 |
# |    ep_rew_mean        | 3.86     |
# | time/                 |          |
# |    fps                | 124      |
# |    iterations         | 18100    |
# |    time_elapsed       | 724      |
# |    total_timesteps    | 90500    |
# | train/                |          |
# |    entropy_loss       | -0.00664 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18099    |
# |    policy_loss        | 8.08e-07 |
# |    value_loss         | 1.55e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.95e+03  |
# |    ep_rew_mean        | 3.86      |
# | time/                 |           |
# |    fps                | 124       |
# |    iterations         | 18200     |
# |    time_elapsed       | 730       |
# |    total_timesteps    | 91000     |
# | train/                |           |
# |    entropy_loss       | -0.00645  |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18199     |
# |    policy_loss        | -2.33e-12 |
# |    value_loss         | 3.17e-15  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.95e+03 |
# |    ep_rew_mean        | 3.86     |
# | time/                 |          |
# |    fps                | 124      |
# |    iterations         | 18300    |
# |    time_elapsed       | 736      |
# |    total_timesteps    | 91500    |
# | train/                |          |
# |    entropy_loss       | -0.00645 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18299    |
# |    policy_loss        | 6.21e-11 |
# |    value_loss         | 2.4e-14  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.95e+03  |
# |    ep_rew_mean        | 3.86      |
# | time/                 |           |
# |    fps                | 123       |
# |    iterations         | 18400     |
# |    time_elapsed       | 742       |
# |    total_timesteps    | 92000     |
# | train/                |           |
# |    entropy_loss       | -0.00645  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18399     |
# |    policy_loss        | -7.28e-11 |
# |    value_loss         | 2.6e-15   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.95e+03  |
# |    ep_rew_mean        | 3.86      |
# | time/                 |           |
# |    fps                | 123       |
# |    iterations         | 18500     |
# |    time_elapsed       | 748       |
# |    total_timesteps    | 92500     |
# | train/                |           |
# |    entropy_loss       | -0.00568  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18499     |
# |    policy_loss        | -5.23e-06 |
# |    value_loss         | 9.21e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.95e+03 |
# |    ep_rew_mean        | 3.86     |
# | time/                 |          |
# |    fps                | 123      |
# |    iterations         | 18600    |
# |    time_elapsed       | 754      |
# |    total_timesteps    | 93000    |
# | train/                |          |
# |    entropy_loss       | -0.00631 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18599    |
# |    policy_loss        | 2.33e-12 |
# |    value_loss         | 1.34e-14 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.95e+03  |
# |    ep_rew_mean        | 3.86      |
# | time/                 |           |
# |    fps                | 123       |
# |    iterations         | 18700     |
# |    time_elapsed       | 760       |
# |    total_timesteps    | 93500     |
# | train/                |           |
# |    entropy_loss       | -0.00618  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18699     |
# |    policy_loss        | -2.39e-07 |
# |    value_loss         | 1.59e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.95e+03 |
# |    ep_rew_mean        | 3.86     |
# | time/                 |          |
# |    fps                | 122      |
# |    iterations         | 18800    |
# |    time_elapsed       | 765      |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -0.00621 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18799    |
# |    policy_loss        | 4.21e-13 |
# |    value_loss         | 4.89e-19 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.95e+03  |
# |    ep_rew_mean        | 3.86      |
# | time/                 |           |
# |    fps                | 122       |
# |    iterations         | 18900     |
# |    time_elapsed       | 771       |
# |    total_timesteps    | 94500     |
# | train/                |           |
# |    entropy_loss       | -0.00621  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18899     |
# |    policy_loss        | -1.18e-11 |
# |    value_loss         | 4.87e-14  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.95e+03  |
# |    ep_rew_mean        | 3.86      |
# | time/                 |           |
# |    fps                | 122       |
# |    iterations         | 19000     |
# |    time_elapsed       | 777       |
# |    total_timesteps    | 95000     |
# | train/                |           |
# |    entropy_loss       | -0.00621  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18999     |
# |    policy_loss        | -3.66e-14 |
# |    value_loss         | 3.7e-21   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.95e+03  |
# |    ep_rew_mean        | 3.86      |
# | time/                 |           |
# |    fps                | 121       |
# |    iterations         | 19100     |
# |    time_elapsed       | 783       |
# |    total_timesteps    | 95500     |
# | train/                |           |
# |    entropy_loss       | -0.00621  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19099     |
# |    policy_loss        | -3.66e-14 |
# |    value_loss         | 3.7e-21   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.95e+03  |
# |    ep_rew_mean        | 3.86      |
# | time/                 |           |
# |    fps                | 121       |
# |    iterations         | 19200     |
# |    time_elapsed       | 788       |
# |    total_timesteps    | 96000     |
# | train/                |           |
# |    entropy_loss       | -0.00621  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19199     |
# |    policy_loss        | -3.66e-14 |
# |    value_loss         | 3.7e-21   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.95e+03  |
# |    ep_rew_mean        | 3.86      |
# | time/                 |           |
# |    fps                | 121       |
# |    iterations         | 19300     |
# |    time_elapsed       | 794       |
# |    total_timesteps    | 96500     |
# | train/                |           |
# |    entropy_loss       | -0.00621  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19299     |
# |    policy_loss        | -3.66e-14 |
# |    value_loss         | 3.7e-21   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.95e+03  |
# |    ep_rew_mean        | 3.86      |
# | time/                 |           |
# |    fps                | 121       |
# |    iterations         | 19400     |
# |    time_elapsed       | 800       |
# |    total_timesteps    | 97000     |
# | train/                |           |
# |    entropy_loss       | -0.00622  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19399     |
# |    policy_loss        | -1.16e-11 |
# |    value_loss         | 6e-15     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.95e+03  |
# |    ep_rew_mean        | 3.86      |
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 19500     |
# |    time_elapsed       | 806       |
# |    total_timesteps    | 97500     |
# | train/                |           |
# |    entropy_loss       | -0.00622  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19499     |
# |    policy_loss        | -1.47e-08 |
# |    value_loss         | 5.9e-10   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.95e+03  |
# |    ep_rew_mean        | 3.86      |
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 19600     |
# |    time_elapsed       | 812       |
# |    total_timesteps    | 98000     |
# | train/                |           |
# |    entropy_loss       | -0.00622  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19599     |
# |    policy_loss        | -1.24e-07 |
# |    value_loss         | 4.26e-08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.95e+03  |
# |    ep_rew_mean        | 3.86      |
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 19700     |
# |    time_elapsed       | 817       |
# |    total_timesteps    | 98500     |
# | train/                |           |
# |    entropy_loss       | -0.00621  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19699     |
# |    policy_loss        | -4.15e-07 |
# |    value_loss         | 4.75e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.95e+03  |
# |    ep_rew_mean        | 3.86      |
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 19800     |
# |    time_elapsed       | 823       |
# |    total_timesteps    | 99000     |
# | train/                |           |
# |    entropy_loss       | -0.00621  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19799     |
# |    policy_loss        | -3.54e-07 |
# |    value_loss         | 3.45e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.95e+03  |
# |    ep_rew_mean        | 3.86      |
# | time/                 |           |
# |    fps                | 120       |
# |    iterations         | 19900     |
# |    time_elapsed       | 829       |
# |    total_timesteps    | 99500     |
# | train/                |           |
# |    entropy_loss       | -0.00621  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19899     |
# |    policy_loss        | -3.05e-07 |
# |    value_loss         | 2.56e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.95e+03  |
# |    ep_rew_mean        | 3.86      |
# | time/                 |           |
# |    fps                | 119       |
# |    iterations         | 20000     |
# |    time_elapsed       | 833       |
# |    total_timesteps    | 100000    |
# | train/                |           |
# |    entropy_loss       | -0.00621  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19999     |
# |    policy_loss        | -3.42e-07 |
# |    value_loss         | 3.23e-07  |
# -------------------------------------
# Mean reward: 0.0 +/- 0.00

# %%
model.save("./saved_models/a2c-breakout")

# %%
tmp_path = "./results/dqn-breakout"
new_logger = configure(tmp_path, ["stdout", "csv", "tensorboard"])

model = DQN(policy = "MlpPolicy", 
            env = env,
            learning_rate=4e-4,
            gamma=0.99,
            exploration_initial_eps=1.0,
            exploration_final_eps=0.01,
            exploration_fraction=0.999,
            buffer_size=10_000,)

model.set_logger(new_logger)
model.learn(total_timesteps=100_000)

mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)
print(f'Mean reward: {mean_reward} +/- {std_reward:.2f}')
# Out:
# Logging to ./results/dqn-breakout
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 252      |
# |    ep_rew_mean      | 3        |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 323      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1008     |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.002    |
# |    n_updates        | 226      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 205      |
# |    ep_rew_mean      | 1.88     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 326      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 1642     |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.0139   |
# |    n_updates        | 385      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.33     |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 325      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 2219     |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.00024  |
# |    n_updates        | 529      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 1.12     |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 321      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2839     |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 7.53e-05 |
# |    n_updates        | 684      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | 1.45     |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 318      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 3804     |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.00213  |
# |    n_updates        | 925      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 1.5      |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 318      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 4618     |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.000995 |
# |    n_updates        | 1129     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 1.43     |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 318      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 5289     |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.00016  |
# |    n_updates        | 1297     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 1.41     |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 320      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 6054     |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 9.69e-05 |
# |    n_updates        | 1488     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 1.39     |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 325      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 6821     |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 8.89e-05 |
# |    n_updates        | 1680     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.27     |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 327      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 7403     |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.000164 |
# |    n_updates        | 1825     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.27     |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 329      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 8130     |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.000163 |
# |    n_updates        | 2007     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 1.25     |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 331      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 8820     |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.0158   |
# |    n_updates        | 2179     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 1.25     |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 332      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 9551     |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 2.83e-05 |
# |    n_updates        | 2362     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.3      |
# |    exploration_rate | 0.897    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 334      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 10388    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.000446 |
# |    n_updates        | 2571     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.28     |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 335      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 11143    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.000149 |
# |    n_updates        | 2760     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 1.33     |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 333      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 12010    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.0151   |
# |    n_updates        | 2977     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 1.34     |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 330      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 12823    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 3.13e-05 |
# |    n_updates        | 3180     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 1.32     |
# |    exploration_rate | 0.866    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 329      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 13555    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.000443 |
# |    n_updates        | 3363     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 1.3      |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 328      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 14223    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 8.28e-05 |
# |    n_updates        | 3530     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.29     |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 327      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 14903    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.0156   |
# |    n_updates        | 3700     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.26     |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 325      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 15572    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.000183 |
# |    n_updates        | 3867     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 1.3      |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 323      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 16427    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 3.05e-05 |
# |    n_updates        | 4081     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 1.33     |
# |    exploration_rate | 0.829    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 321      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 17247    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 6.6e-05  |
# |    n_updates        | 4286     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 1.35     |
# |    exploration_rate | 0.82     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 320      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 18119    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 8.07e-05 |
# |    n_updates        | 4504     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 1.33     |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 318      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 18802    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 6.35e-05 |
# |    n_updates        | 4675     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.27     |
# |    exploration_rate | 0.806    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 316      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 19594    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.0157   |
# |    n_updates        | 4873     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.26     |
# |    exploration_rate | 0.8      |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 314      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 20216    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.000852 |
# |    n_updates        | 5028     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 1.32     |
# |    exploration_rate | 0.792    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 312      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 21011    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.000202 |
# |    n_updates        | 5227     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | 1.38     |
# |    exploration_rate | 0.783    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 311      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 21854    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.000423 |
# |    n_updates        | 5438     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 1.34     |
# |    exploration_rate | 0.776    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 309      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 22629    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 2.53e-05 |
# |    n_updates        | 5632     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.29     |
# |    exploration_rate | 0.77     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 308      |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 23219    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.000263 |
# |    n_updates        | 5779     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 1.3      |
# |    exploration_rate | 0.762    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 306      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 23979    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.00016  |
# |    n_updates        | 5969     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 1.3      |
# |    exploration_rate | 0.755    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 304      |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 24720    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.0149   |
# |    n_updates        | 6154     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 1.34     |
# |    exploration_rate | 0.746    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 300      |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 25595    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.000301 |
# |    n_updates        | 6373     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | 1.38     |
# |    exploration_rate | 0.739    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 296      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 26363    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.0311   |
# |    n_updates        | 6565     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 1.37     |
# |    exploration_rate | 0.732    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 293      |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 27074    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 3.26e-05 |
# |    n_updates        | 6743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 1.4      |
# |    exploration_rate | 0.724    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 290      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 27887    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 1.39e-05 |
# |    n_updates        | 6946     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 1.4      |
# |    exploration_rate | 0.716    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 289      |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 28650    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.000405 |
# |    n_updates        | 7137     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 1.42     |
# |    exploration_rate | 0.707    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 287      |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 29570    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 7.09e-05 |
# |    n_updates        | 7367     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 1.48     |
# |    exploration_rate | 0.698    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 286      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 30521    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 2.27e-05 |
# |    n_updates        | 7605     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 1.44     |
# |    exploration_rate | 0.691    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 283      |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 31201    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 3.09e-05 |
# |    n_updates        | 7775     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 1.5      |
# |    exploration_rate | 0.681    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 280      |
# |    time_elapsed     | 114      |
# |    total_timesteps  | 32203    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 4.08e-05 |
# |    n_updates        | 8025     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 1.53     |
# |    exploration_rate | 0.673    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 278      |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 33030    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.000445 |
# |    n_updates        | 8232     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 1.57     |
# |    exploration_rate | 0.664    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 276      |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 33864    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.000106 |
# |    n_updates        | 8440     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 1.61     |
# |    exploration_rate | 0.656    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 274      |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 34731    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 2.86e-05 |
# |    n_updates        | 8657     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 1.62     |
# |    exploration_rate | 0.649    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 273      |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 35415    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 6.21e-05 |
# |    n_updates        | 8828     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 1.61     |
# |    exploration_rate | 0.641    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 271      |
# |    time_elapsed     | 133      |
# |    total_timesteps  | 36238    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 3.48e-05 |
# |    n_updates        | 9034     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 1.57     |
# |    exploration_rate | 0.634    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 270      |
# |    time_elapsed     | 136      |
# |    total_timesteps  | 36970    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 1.59e-05 |
# |    n_updates        | 9217     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 1.59     |
# |    exploration_rate | 0.624    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 269      |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 37944    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.0153   |
# |    n_updates        | 9460     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 1.63     |
# |    exploration_rate | 0.616    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 268      |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 38739    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.0155   |
# |    n_updates        | 9659     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 1.65     |
# |    exploration_rate | 0.607    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 268      |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 39616    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 3.84e-05 |
# |    n_updates        | 9878     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | 1.72     |
# |    exploration_rate | 0.599    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 267      |
# |    time_elapsed     | 151      |
# |    total_timesteps  | 40464    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.0155   |
# |    n_updates        | 10090    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 205      |
# |    ep_rew_mean      | 1.77     |
# |    exploration_rate | 0.588    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 266      |
# |    time_elapsed     | 155      |
# |    total_timesteps  | 41549    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 3.42e-05 |
# |    n_updates        | 10362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 205      |
# |    ep_rew_mean      | 1.77     |
# |    exploration_rate | 0.58     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 265      |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 42385    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 4.61e-05 |
# |    n_updates        | 10571    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 206      |
# |    ep_rew_mean      | 1.78     |
# |    exploration_rate | 0.571    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 261      |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 43255    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 7.41e-05 |
# |    n_updates        | 10788    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 208      |
# |    ep_rew_mean      | 1.84     |
# |    exploration_rate | 0.564    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 258      |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 44043    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 1.02e-05 |
# |    n_updates        | 10985    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 211      |
# |    ep_rew_mean      | 1.9      |
# |    exploration_rate | 0.554    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 255      |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 45045    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.000926 |
# |    n_updates        | 11236    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 212      |
# |    ep_rew_mean      | 1.92     |
# |    exploration_rate | 0.545    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 252      |
# |    time_elapsed     | 181      |
# |    total_timesteps  | 45916    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 6.35e-05 |
# |    n_updates        | 11453    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 210      |
# |    ep_rew_mean      | 1.88     |
# |    exploration_rate | 0.538    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 250      |
# |    time_elapsed     | 186      |
# |    total_timesteps  | 46642    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 3.63e-05 |
# |    n_updates        | 11635    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 211      |
# |    ep_rew_mean      | 1.89     |
# |    exploration_rate | 0.53     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 248      |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 47435    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 9.2e-05  |
# |    n_updates        | 11833    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 211      |
# |    ep_rew_mean      | 1.89     |
# |    exploration_rate | 0.523    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 246      |
# |    time_elapsed     | 195      |
# |    total_timesteps  | 48148    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 6.26e-05 |
# |    n_updates        | 12011    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 211      |
# |    ep_rew_mean      | 1.88     |
# |    exploration_rate | 0.515    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 244      |
# |    time_elapsed     | 200      |
# |    total_timesteps  | 48976    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 2.16e-05 |
# |    n_updates        | 12218    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 211      |
# |    ep_rew_mean      | 1.9      |
# |    exploration_rate | 0.507    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 242      |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 49790    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 1.85e-05 |
# |    n_updates        | 12422    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 210      |
# |    ep_rew_mean      | 1.85     |
# |    exploration_rate | 0.499    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 241      |
# |    time_elapsed     | 209      |
# |    total_timesteps  | 50533    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 3.56e-05 |
# |    n_updates        | 12608    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 210      |
# |    ep_rew_mean      | 1.85     |
# |    exploration_rate | 0.489    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 239      |
# |    time_elapsed     | 215      |
# |    total_timesteps  | 51554    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.0159   |
# |    n_updates        | 12863    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 215      |
# |    ep_rew_mean      | 1.94     |
# |    exploration_rate | 0.478    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 237      |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 52656    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.0154   |
# |    n_updates        | 13138    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 211      |
# |    ep_rew_mean      | 1.85     |
# |    exploration_rate | 0.471    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 236      |
# |    time_elapsed     | 225      |
# |    total_timesteps  | 53340    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.00056  |
# |    n_updates        | 13309    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 213      |
# |    ep_rew_mean      | 1.92     |
# |    exploration_rate | 0.462    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 234      |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 54303    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.000493 |
# |    n_updates        | 13550    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 211      |
# |    ep_rew_mean      | 1.89     |
# |    exploration_rate | 0.455    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 233      |
# |    time_elapsed     | 235      |
# |    total_timesteps  | 55007    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 8.76e-05 |
# |    n_updates        | 13726    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 211      |
# |    ep_rew_mean      | 1.88     |
# |    exploration_rate | 0.447    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 232      |
# |    time_elapsed     | 239      |
# |    total_timesteps  | 55847    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 2.2e-05  |
# |    n_updates        | 13936    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 213      |
# |    ep_rew_mean      | 1.91     |
# |    exploration_rate | 0.438    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 231      |
# |    time_elapsed     | 244      |
# |    total_timesteps  | 56670    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 1.43e-05 |
# |    n_updates        | 14142    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 213      |
# |    ep_rew_mean      | 1.89     |
# |    exploration_rate | 0.43     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 230      |
# |    time_elapsed     | 249      |
# |    total_timesteps  | 57493    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.000457 |
# |    n_updates        | 14348    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | 1.99     |
# |    exploration_rate | 0.42     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 229      |
# |    time_elapsed     | 255      |
# |    total_timesteps  | 58531    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 5.1e-05  |
# |    n_updates        | 14607    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 214      |
# |    ep_rew_mean      | 1.95     |
# |    exploration_rate | 0.412    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 227      |
# |    time_elapsed     | 260      |
# |    total_timesteps  | 59333    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 6.45e-06 |
# |    n_updates        | 14808    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | 2        |
# |    exploration_rate | 0.402    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 226      |
# |    time_elapsed     | 266      |
# |    total_timesteps  | 60316    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 3.96e-05 |
# |    n_updates        | 15053    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | 2        |
# |    exploration_rate | 0.393    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 225      |
# |    time_elapsed     | 271      |
# |    total_timesteps  | 61215    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.0154   |
# |    n_updates        | 15278    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 217      |
# |    ep_rew_mean      | 2.01     |
# |    exploration_rate | 0.384    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 223      |
# |    time_elapsed     | 278      |
# |    total_timesteps  | 62199    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 4.91e-05 |
# |    n_updates        | 15524    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 217      |
# |    ep_rew_mean      | 2.02     |
# |    exploration_rate | 0.373    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 221      |
# |    time_elapsed     | 285      |
# |    total_timesteps  | 63253    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 3.99e-06 |
# |    n_updates        | 15788    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 219      |
# |    ep_rew_mean      | 2.05     |
# |    exploration_rate | 0.362    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 220      |
# |    time_elapsed     | 291      |
# |    total_timesteps  | 64330    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 2.39e-05 |
# |    n_updates        | 16057    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 225      |
# |    ep_rew_mean      | 2.16     |
# |    exploration_rate | 0.349    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 218      |
# |    time_elapsed     | 301      |
# |    total_timesteps  | 65715    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 7.09e-05 |
# |    n_updates        | 16403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 225      |
# |    ep_rew_mean      | 2.15     |
# |    exploration_rate | 0.341    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 216      |
# |    time_elapsed     | 306      |
# |    total_timesteps  | 66548    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 2.1e-05  |
# |    n_updates        | 16611    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 224      |
# |    ep_rew_mean      | 2.13     |
# |    exploration_rate | 0.332    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 215      |
# |    time_elapsed     | 312      |
# |    total_timesteps  | 67440    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 5.31e-05 |
# |    n_updates        | 16834    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 225      |
# |    ep_rew_mean      | 2.15     |
# |    exploration_rate | 0.322    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 214      |
# |    time_elapsed     | 319      |
# |    total_timesteps  | 68424    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.0152   |
# |    n_updates        | 17080    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 227      |
# |    ep_rew_mean      | 2.17     |
# |    exploration_rate | 0.313    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 213      |
# |    time_elapsed     | 324      |
# |    total_timesteps  | 69313    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 7.41e-05 |
# |    n_updates        | 17303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 227      |
# |    ep_rew_mean      | 2.17     |
# |    exploration_rate | 0.305    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 212      |
# |    time_elapsed     | 330      |
# |    total_timesteps  | 70179    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 1.24e-05 |
# |    n_updates        | 17519    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 228      |
# |    ep_rew_mean      | 2.17     |
# |    exploration_rate | 0.297    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 211      |
# |    time_elapsed     | 334      |
# |    total_timesteps  | 70942    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 2.23e-05 |
# |    n_updates        | 17710    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 231      |
# |    ep_rew_mean      | 2.28     |
# |    exploration_rate | 0.286    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 210      |
# |    time_elapsed     | 341      |
# |    total_timesteps  | 72056    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.00058  |
# |    n_updates        | 17988    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 232      |
# |    ep_rew_mean      | 2.29     |
# |    exploration_rate | 0.277    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 209      |
# |    time_elapsed     | 348      |
# |    total_timesteps  | 72952    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 5.78e-05 |
# |    n_updates        | 18212    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 233      |
# |    ep_rew_mean      | 2.36     |
# |    exploration_rate | 0.268    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 208      |
# |    time_elapsed     | 354      |
# |    total_timesteps  | 73824    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 7.85e-05 |
# |    n_updates        | 18430    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 232      |
# |    ep_rew_mean      | 2.34     |
# |    exploration_rate | 0.259    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 207      |
# |    time_elapsed     | 360      |
# |    total_timesteps  | 74764    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 1.01e-05 |
# |    n_updates        | 18665    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 231      |
# |    ep_rew_mean      | 2.35     |
# |    exploration_rate | 0.249    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 206      |
# |    time_elapsed     | 366      |
# |    total_timesteps  | 75757    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.0161   |
# |    n_updates        | 18914    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 235      |
# |    ep_rew_mean      | 2.45     |
# |    exploration_rate | 0.239    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 206      |
# |    time_elapsed     | 372      |
# |    total_timesteps  | 76837    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 8.85e-05 |
# |    n_updates        | 19184    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 237      |
# |    ep_rew_mean      | 2.44     |
# |    exploration_rate | 0.227    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 205      |
# |    time_elapsed     | 378      |
# |    total_timesteps  | 78039    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 7.11e-05 |
# |    n_updates        | 19484    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 241      |
# |    ep_rew_mean      | 2.5      |
# |    exploration_rate | 0.216    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 205      |
# |    time_elapsed     | 384      |
# |    total_timesteps  | 79151    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 2.76e-05 |
# |    n_updates        | 19762    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 245      |
# |    ep_rew_mean      | 2.56     |
# |    exploration_rate | 0.204    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 205      |
# |    time_elapsed     | 390      |
# |    total_timesteps  | 80373    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 3.09e-05 |
# |    n_updates        | 20068    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 246      |
# |    ep_rew_mean      | 2.55     |
# |    exploration_rate | 0.195    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 205      |
# |    time_elapsed     | 395      |
# |    total_timesteps  | 81270    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 4.91e-05 |
# |    n_updates        | 20292    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 249      |
# |    ep_rew_mean      | 2.59     |
# |    exploration_rate | 0.183    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 205      |
# |    time_elapsed     | 401      |
# |    total_timesteps  | 82436    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 1.58e-05 |
# |    n_updates        | 20583    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 253      |
# |    ep_rew_mean      | 2.56     |
# |    exploration_rate | 0.17     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 204      |
# |    time_elapsed     | 409      |
# |    total_timesteps  | 83801    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.000856 |
# |    n_updates        | 20925    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 256      |
# |    ep_rew_mean      | 2.57     |
# |    exploration_rate | 0.158    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 204      |
# |    time_elapsed     | 414      |
# |    total_timesteps  | 84955    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.000701 |
# |    n_updates        | 21213    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 258      |
# |    ep_rew_mean      | 2.55     |
# |    exploration_rate | 0.146    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 205      |
# |    time_elapsed     | 419      |
# |    total_timesteps  | 86140    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.0155   |
# |    n_updates        | 21509    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 257      |
# |    ep_rew_mean      | 2.52     |
# |    exploration_rate | 0.139    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 205      |
# |    time_elapsed     | 422      |
# |    total_timesteps  | 86904    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 4.27e-05 |
# |    n_updates        | 21700    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 260      |
# |    ep_rew_mean      | 2.58     |
# |    exploration_rate | 0.126    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 206      |
# |    time_elapsed     | 427      |
# |    total_timesteps  | 88181    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.0157   |
# |    n_updates        | 22020    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 260      |
# |    ep_rew_mean      | 2.55     |
# |    exploration_rate | 0.115    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 207      |
# |    time_elapsed     | 431      |
# |    total_timesteps  | 89290    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 6.38e-05 |
# |    n_updates        | 22297    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 260      |
# |    ep_rew_mean      | 2.49     |
# |    exploration_rate | 0.105    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 207      |
# |    time_elapsed     | 435      |
# |    total_timesteps  | 90337    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.000792 |
# |    n_updates        | 22559    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 261      |
# |    ep_rew_mean      | 2.41     |
# |    exploration_rate | 0.0906   |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 208      |
# |    time_elapsed     | 440      |
# |    total_timesteps  | 91769    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 7.78e-05 |
# |    n_updates        | 22917    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 259      |
# |    ep_rew_mean      | 2.36     |
# |    exploration_rate | 0.0838   |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 208      |
# |    time_elapsed     | 443      |
# |    total_timesteps  | 92455    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 1.81e-05 |
# |    n_updates        | 23088    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 265      |
# |    ep_rew_mean      | 2.4      |
# |    exploration_rate | 0.0695   |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 209      |
# |    time_elapsed     | 448      |
# |    total_timesteps  | 93900    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 0.0155   |
# |    n_updates        | 23449    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 270      |
# |    ep_rew_mean      | 2.43     |
# |    exploration_rate | 0.0543   |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 209      |
# |    time_elapsed     | 455      |
# |    total_timesteps  | 95431    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 2.5e-05  |
# |    n_updates        | 23832    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 276      |
# |    ep_rew_mean      | 2.44     |
# |    exploration_rate | 0.0398   |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 210      |
# |    time_elapsed     | 461      |
# |    total_timesteps  | 96893    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 2.4e-05  |
# |    n_updates        | 24198    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 278      |
# |    ep_rew_mean      | 2.39     |
# |    exploration_rate | 0.029    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 210      |
# |    time_elapsed     | 465      |
# |    total_timesteps  | 97981    |
# | train/              |          |
# |    learning_rate    | 0.0004   |
# |    loss             | 1.52e-05 |
# |    n_updates        | 24470    |
# ----------------------------------
# Mean reward: 0.0 +/- 0.00

# %%
model.save("./saved_models/dqn-breakout")
